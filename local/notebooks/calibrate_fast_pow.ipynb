# %%
# -------------------------------------
# --- Go to correct starting folder ---
# -------------------------------------
# (when running jupyter lab in the browser, the notebook starts with CWD = folder where it is located, which breaks imports, ...)
import os
import pathlib

while not ((cwd := pathlib.Path(os.getcwd())) / "pyproject.toml").exists():
    os.chdir(cwd.parent)  # go 1 folder up

# %%
import math

from numpy import linspace

from max_div.internal.math.fast_pow._calibration import calibrate_fast_pow

# %%
# c_opt, d_opt = calibrate_fast_pow(n_data=100_000, acc=1e-16, n_evals=1_000_000, start_from_current_optimum=False)
c_opt, d_opt = calibrate_fast_pow(n_data=100_000, acc=1e-16, n_evals=2_500_000, start_from_current_optimum=True)
# Out:
# |        % |               max(size) |                   f_opt |                    x[0] |                    x[1] |                    x[2] |                    x[3] |
# | -------- | ----------------------- | ----------------------- | ----------------------- | ----------------------- | ----------------------- | ----------------------- |
# |     0.0% |  0.20000000000000017764 |  0.00206880477124748345 | -2.63266261514541488609 |  3.89274362006841956330 |  0.99917710370794909913 |  0.67296844892616181077 |
# |     0.7% |  0.14889419121408789537 |  0.00206880477124748345 | -2.63266261514541488609 |  3.89274362006841956330 |  0.99917710370794909913 |  0.67296844892616181077 |
# |     1.5% |  0.11084740088648546708 |  0.00206880477124748345 | -2.63266261514541488609 |  3.89274362006841956330 |  0.99917710370794909913 |  0.67296844892616181077 |
# ...
